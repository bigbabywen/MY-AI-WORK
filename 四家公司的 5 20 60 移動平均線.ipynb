# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas_datareader.data as web
from matplotlib import dates as mdates
from matplotlib import ticker as mticker
import mplfinance as mpf
from matplotlib.dates import DateFormatter
import pandas_datareader.data as web

# %%
df1 = web.DataReader("AAPL",  "yahoo", start="2018-1-1",end="2019-12-31")
df2 = web.DataReader("GOOGL",  "yahoo", start="2018-1-1",end="2019-12-31")
df3 = web.DataReader("KO",  "yahoo", start="2018-1-1",end="2019-12-31")
df4 = web.DataReader("AMZN",  "yahoo", start="2018-1-1",end="2019-12-31")

# %%
df1.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02  172.300003  169.259995  170.160004  172.259995  25555900.0
# 2018-01-03  174.550003  171.960007  172.529999  172.229996  29517900.0
# 2018-01-04  173.470001  172.080002  172.539993  173.029999  22434600.0
# 2018-01-05  175.369995  173.050003  173.440002  175.000000  23660000.0
# 2018-01-08  175.610001  173.929993  174.350006  174.350006  20567800.0
#
#              Adj Close
# Date
# 2018-01-02  166.353714
# 2018-01-03  166.324722
# 2018-01-04  167.097290
# 2018-01-05  168.999741
# 2018-01-08  168.372040

# %%
P1 =df1["Adj Close"]
P2 =df2["Adj Close"]
P3 =df3["Adj Close"]
P4 =df4["Adj Close"]

# %%
P1.rolling(window=5).mean().plot()
P1.rolling(window=20).mean().plot()
P1.rolling(window=60).mean().plot()

# %%
P2.rolling(window=5).mean().plot()
P2.rolling(window=20).mean().plot()
P2.rolling(window=60).mean().plot()

# %%
P3.rolling(window=5).mean().plot()
P3.rolling(window=20).mean().plot()
P3.rolling(window=60).mean().plot()

# %%
P4.rolling(window=5).mean().plot()
P4.rolling(window=20).mean().plot()
P4.rolling(window=60).mean().plot()
