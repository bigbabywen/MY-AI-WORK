# %%
L=["甲", "乙","丙", "丁", "戊", "己", "庚", "辛", "壬", "癸"]

M=["子", "醜", "寅", "卯", "辰", "巳", "午", "未", "申", "酉", "戌", "亥"]

# %%
for i in range(2014, 2074):
    print(str(i)+"是"+str(L[(i-4)%10])+str(M[(i-4)%12])+"年")
# Out:
# 2014是甲午年
# 2015是乙未年
# 2016是丙申年
# 2017是丁酉年
# 2018是戊戌年
# 2019是己亥年
# 2020是庚子年
# 2021是辛醜年
# 2022是壬寅年
# 2023是癸卯年
# 2024是甲辰年
# 2025是乙巳年
# 2026是丙午年
# 2027是丁未年
# 2028是戊申年
# 2029是己酉年
# 2030是庚戌年
# 2031是辛亥年
# 2032是壬子年
# 2033是癸醜年
# 2034是甲寅年
# 2035是乙卯年
# 2036是丙辰年
# 2037是丁巳年
# 2038是戊午年
# 2039是己未年
# 2040是庚申年
# 2041是辛酉年
# 2042是壬戌年
# 2043是癸亥年
# 2044是甲子年
# 2045是乙醜年
# 2046是丙寅年
# 2047是丁卯年
# 2048是戊辰年
# 2049是己巳年
# 2050是庚午年
# 2051是辛未年
# 2052是壬申年
# 2053是癸酉年
# 2054是甲戌年
# 2055是乙亥年
# 2056是丙子年
# 2057是丁醜年
# 2058是戊寅年
# 2059是己卯年
# 2060是庚辰年
# 2061是辛巳年
# 2062是壬午年
# 2063是癸未年
# 2064是甲申年
# 2065是乙酉年
# 2066是丙戌年
# 2067是丁亥年
# 2068是戊子年
# 2069是己醜年
# 2070是庚寅年
# 2071是辛卯年
# 2072是壬辰年
# 2073是癸巳年
